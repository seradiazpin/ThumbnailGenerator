# %%
import Augmentor
from PIL import Image
import os
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid


PATH = "..\\..\\ThumbnailGenerator\\Actividad 4\\TestImage\\"

def plot_img(imgs):
    
    fig = plt.figure(figsize=(30., 30.))
    grid = ImageGrid(fig, 111,  
                     nrows_ncols=(3, 4), 
                     axes_pad=0.1, 
                     )

    for ax, im in zip(grid, imgs):
        # Iterating over the grid returns the Axes.
        ax.imshow(im)
        ax.spines['top'].set_visible(False)
        ax.spines['left'].set_visible(False)
        ax.spines['bottom'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.set_xticks([])
        ax.set_yticks([])

def reset_pipeline_flip(path, flip=True):
    p = Augmentor.Pipeline(path)
    if flip:
        p.flip_left_right(probability=1)
    return p

def augmentation_examples(PATH):
        
    # More brigthness
    p = reset_pipeline_flip(PATH)
    p.random_brightness(probability=1.0, min_factor=0.5, max_factor=1.0)
    p.sample(1)
    
    # less brigthness
    p = reset_pipeline_flip(PATH)
    p.random_brightness(probability=1.0, min_factor=0.5, max_factor=1.0)
    p.sample(1)

    #  random_color
    p = reset_pipeline_flip(PATH)
    p.random_color(probability=1.0, min_factor=0.3, max_factor=0.6)
    p.sample(1)
    
    # random_contrast
    p = reset_pipeline_flip(PATH)
    p.random_contrast(probability=1.0, min_factor=0.2, max_factor=0.5)
    p.sample(1)

    # 4 - random_distortion
    p = reset_pipeline_flip(PATH,False)
    p.random_distortion(probability=1, grid_width=16, grid_height=16, magnitude=8)
    p.sample(1)
    
    # 5 - crop_random 90%
    p = reset_pipeline_flip(PATH,False)
    p.crop_random(probability=1, percentage_area=0.9)
    p.resize(probability=1.0, width=1920, height=1080)
    p.sample(1)
    
    p = reset_pipeline_flip(PATH,False)
    p.shear(probability=1, max_shear_left = 5, max_shear_right = 5)
    p.sample(1)
    p.sample(1)
    p.sample(1)
    
    p = reset_pipeline_flip(PATH,False)
    p.skew(probability=1, magnitude=0.3)
    p.sample(1)
    p.sample(1)
    p.sample(1)
    
def augmentation_examples_flip(PATH):
    # Flip
    p = reset_pipeline_flip(PATH)
    p.sample(1)
    
    # More brigthness
    p = reset_pipeline_flip(PATH)
    p.random_brightness(probability=1.0, min_factor=0.5, max_factor=1.0)
    p.sample(1)
    
    # less brigthness
    p = reset_pipeline_flip(PATH)
    p.random_brightness(probability=1.0, min_factor=0.5, max_factor=1.0)
    p.sample(1)

    # random_color
    p = reset_pipeline_flip(PATH)
    p.random_color(probability=1.0, min_factor=0.3, max_factor=0.6)
    p.sample(1)

    # random_contrast
    p = reset_pipeline_flip(PATH)
    p.random_contrast(probability=1.0, min_factor=0.2, max_factor=0.5)
    p.sample(1)

    # random_distortion
    p = reset_pipeline_flip(PATH)
    p.random_distortion(probability=1, grid_width=16, grid_height=16, magnitude=8)
    p.sample(1)
    
    # crop_random 90%
    p = reset_pipeline_flip(PATH)
    p.crop_random(probability=1, percentage_area=0.9)
    p.resize(probability=1.0, width=1920, height=1080)
    p.sample(1)
    
    p = reset_pipeline_flip(PATH)
    p.shear(probability=1, max_shear_left = 5, max_shear_right = 5)
    p.sample(1)
    p.sample(1)
    p.sample(1)
    
    p = reset_pipeline_flip(PATH)
    p.skew(probability=1, magnitude=0.3)
    p.sample(1)
    p.sample(1)
    p.sample(1)

# %%
augmentation_examples(PATH)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90CF6C08>: 100%|█| 1/1 [00:00<00:00, 26.32 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90ADAFC8>: 100%|█| 1/1 [00:00<00:00, 28.57 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90ADAB48>: 100%|█| 1/1 [00:00<00:00, 26.32 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90AC9A48>: 100%|█| 1/1 [00:00<00:00, 24.39 Samples/s]
# Executing Pipeline:   0%|                                                                  | 0/1 [00:00<?, ? Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImage\output.Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImage\output.Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImage\output.Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImage\output.Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImage\output.
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90972248>: 100%|█| 1/1 [00:00<00:00,  6.71 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90ADABC8>: 100%|█| 1/1 [00:00<00:00, 20.84 Samples/s]
# Executing Pipeline:   0%|                                                                  | 0/1 [00:00<?, ? Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImage\output.Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImage\output.
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90CC1408>: 100%|█| 1/1 [00:00<00:00,  6.06 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90CC0C88>: 100%|█| 1/1 [00:00<00:00,  6.14 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90AC9848>: 100%|█| 1/1 [00:00<00:00,  6.13 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90AC9788>: 100%|█| 1/1 [00:00<00:00,  6.76 Samples/s]
# Executing Pipeline:   0%|                                                                  | 0/1 [00:00<?, ? Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImage\output.
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90AC9608>: 100%|█| 1/1 [00:00<00:00,  6.71 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90AC9708>: 100%|█| 1/1 [00:00<00:00,  6.58 Samples/s]

# %%
PATH_OUT = "..\\..\\ThumbnailGenerator\\Actividad 4\\TestImage\\output\\"
imgs = []
for i in os.listdir(PATH_OUT):
    imgs.append(Image.open(os.path.join(PATH_OUT,i)))

plot_img(imgs)

# %%
PATH = "..\\..\\ThumbnailGenerator\\Actividad 4\\TestImageFlip\\"
augmentation_examples_flip(PATH)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F8FD1E6C8>: 100%|█| 1/1 [00:00<00:00, 41.01 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F8F900588>: 100%|█| 1/1 [00:00<00:00, 31.25 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F9080E888>: 100%|█| 1/1 [00:00<00:00, 30.30 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F8F8E9C08>: 100%|█| 1/1 [00:00<00:00, 26.32 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90288808>:   0%|         | 0/1 [00:00<?, ? Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImageFlip\output.Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImageFlip\output.Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImageFlip\output.Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImageFlip\output.Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImageFlip\output.
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F90288808>: 100%|█| 1/1 [00:00<00:00, 24.39 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F8F8FBE48>: 100%|█| 1/1 [00:00<00:00,  6.54 Samples/s]
# Executing Pipeline:   0%|                                                                  | 0/1 [00:00<?, ? Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImageFlip\output.Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImageFlip\output.
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F8FF6B3C8>: 100%|█| 1/1 [00:00<00:00, 19.61 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F8FF6B988>: 100%|█| 1/1 [00:00<00:00,  6.02 Samples/s]
# Executing Pipeline:   0%|                                                                  | 0/1 [00:00<?, ? Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImageFlip\output.
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F8FF6B4C8>: 100%|█| 1/1 [00:00<00:00,  5.68 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F8FF6B5C8>: 100%|█| 1/1 [00:00<00:00,  5.99 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F8FF6BC08>: 100%|█| 1/1 [00:00<00:00,  6.45 Samples/s]
# Executing Pipeline:   0%|                                                                  | 0/1 [00:00<?, ? Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to ..\..\ThumbnailGenerator\Actividad 4\TestImageFlip\output.
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F8FF6B688>: 100%|█| 1/1 [00:00<00:00,  6.37 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=1920x1080 at 0x13F8FF6B488>: 100%|█| 1/1 [00:00<00:00,  6.37 Samples/s]

# %%
PATH_OUT = "..\\..\\ThumbnailGenerator\\Actividad 4\\TestImageFlip\\output\\"
imgs = []
for i in os.listdir(PATH_OUT):
    imgs.append(Image.open(os.path.join(PATH_OUT,i)))

plot_img(imgs)
